# %%
from sqlalchemy import  create_engine, Column, Integer, String, Date,Table
from sqlalchemy.ext.declarative import declarative_base
import pandas as pd
import sqlalchemy
import requests
from datetime import datetime

Base=declarative_base()
class MediaDetails(Base):
        engine = create_engine("mysql+mysqlconnector://root:root@localhost:3306/mediadb")
        conn= engine.connect()
  

        Id= Column(String(50),primary_key=True)
        Title = Column(String(50))
        Release_year = Column(Integer())
        Genres = Column(String(50))
        Description = Column(String(100))
        Theatre = Column(String(100))

        __tablename__ = "tv_Movies"
        Id= Column(String(50),primary_key=True)
        Title = Column(String(50))
        Release_year = Column(Integer())
        Genres = Column(String(50))
        Description = Column(String(100))
        Channel= Column(String(100))

        Base.metadata.create_all(engine)
        line_up_id="USA-TX42500-X"
        date_time=datetime.now().isoformat()

        req1= requests.get("http://data.tmsapi.com/v1.1/movies/showings?startDate=2020-10-29&zip=78701&api_key=qu2a3vcggtdmxm88c4fjpsmj")
        req2 = requests.get("http://data.tmsapi.com/v1.1/movies/airings?lineupId=USA-TX42500-X&startDateTime=2020-10-29T17%3A30Z&endDateTime=2020-10-29&api_key=qu2a3vcggtdmxm88c4fjpsmj")
        print(req1.status_code)
        if req1.status_code==200:
            values=req1.json()
            df1=pd.DataFrame.form_records(values)
            print(df1)
   
        if req2.status_code==200:
            values=req2.json()
           # conn.execute(tv_Movies.insert(),values)
       

        Session = sqlalchemy.orm.sessionmaker()
        Session.configure(bind=engine)
        session = Session()
        session.commit()
# Out:
# 403

# %%
import pandas as pd
df1=pd.read_json("theatreMovies.json")
df2=pd.read_json("tvMoviesResp.json")

# %%
df1
# Out:
#              tmsId    rootId        subType  \
# 0   MV011727750000  15678713   Feature Film
# 1   MV013787510000  17905855   Feature Film
# 2   MV013618560000  17758177   Feature Film
# 3   MV001067170000     27575   Feature Film
# 4   MV000184260000      8572   Feature Film
# 5   MV000371150000     14911   Feature Film
# 6   MV011728530000  15680009   Feature Film
# 7   MV013942100000  18082622   Feature Film
# 8   MV000227710000     10177   Feature Film
# 9   MV000197500000      9070   Feature Film
# 10  MV000247340000     10703   Feature Film
# 11  MV000004670000       283   Feature Film
# 12  MV013065370000  17387266   Feature Film
# 13  MV013072000000  17395468   Feature Film
# 14  MV013450420000  17628255   Feature Film
# 15  MV000376420000     15096   Feature Film
# 16  MV001060870000     27462   Feature Film
# 17  MV013711250000  17842770   Feature Film
# 18  MV009141240000  13107896   Feature Film
# 19  MV015305700000  18936062   Feature Film
# ...

# %%
df1=df1[['title','releaseYear','genres','shortDescription','showtimes']]
df2=df2[['program','channels']]

# %%
df2
# Out:
#                                                program channels
# 0    {'tmsId': 'MV010921590000', 'rootId': '1522622...    [581]
# 1    {'tmsId': 'MV001802980000', 'rootId': '162826'...    [050]
# 2    {'tmsId': 'MV001802980000', 'rootId': '162826'...    [117]
# 3    {'tmsId': 'MV000439270000', 'rootId': '17341',...    [605]
# 4    {'tmsId': 'MV003677600000', 'rootId': '8774994...    [603]
# ..                                                 ...      ...
# 419  {'tmsId': 'MV002273100000', 'rootId': '182355'...    [083]
# 420  {'tmsId': 'MV002273100000', 'rootId': '182355'...    [632]
# 421  {'tmsId': 'MV003383320000', 'rootId': '16593',...    [596]
# 422  {'tmsId': 'MV007631040000', 'rootId': '1180613...    [535]
# 423  {'tmsId': 'MV003869180000', 'rootId': '9069371...    [585]
#
# [424 rows x 2 columns]

# %%
dt=[]
for i in range(len(df2)):
     d={'title':df2['program'][i]['title'],'genres':df2['program'][i]['genres'],'channels':df2['channels'][i]}
     dt.append(d)

# %%
df3=pd.DataFrame.from_records(dt)

# %%
df3
# Out:
#                                             title  \
# 0                Once Upon a Time... In Hollywood
# 1                                 Freedom Writers
# 2                                 Freedom Writers
# 3                          The American President
# 4                                    Total Recall
# ..                                            ...
# 419                                 Transporter 3
# 420                                 Transporter 3
# 421  Texas Chainsaw Massacre: The Next Generation
# 422                                  Crimson Peak
# 423                                La cara oculta
#
#                                    genres channels
# 0             [Comedy drama, Dark comedy]    [581]
# 1                                 [Drama]    [050]
# 2                                 [Drama]    [117]
# 3                 [Romance, Comedy drama]    [605]
# 4    [Science fiction, Action, Adventure]    [603]
# ..                                    ...      ...
# ...

# %%
df1
# Out:
#                                    title  releaseYear  \
# 0                         Turtle Odyssey       2018.0
# 1                    Into America's Wild       2020.0
# 2                                  Tenet       2020.0
# 3                                  Shrek       2001.0
# 4              A Nightmare on Elm Street       1984.0
# 5                            Hocus Pocus       1993.0
# 6                                  Mandy       2018.0
# 7                              Come Play       2020.0
# 8                          The Lost Boys       1987.0
# 9                            The Goonies       1985.0
# 10                           Beetlejuice       1988.0
# 11                                Psycho       1960.0
# 12                            Synchronic       2019.0
# 13                          Honest Thief       2020.0
# 14                           Yellow Rose       2019.0
# 15        The Nightmare Before Christmas       1993.0
# ...

# %%
df3
# Out:
#                                             title  \
# 0                Once Upon a Time... In Hollywood
# 1                                 Freedom Writers
# 2                                 Freedom Writers
# 3                          The American President
# 4                                    Total Recall
# ..                                            ...
# 419                                 Transporter 3
# 420                                 Transporter 3
# 421  Texas Chainsaw Massacre: The Next Generation
# 422                                  Crimson Peak
# 423                                La cara oculta
#
#                                    genres channels
# 0             [Comedy drama, Dark comedy]    [581]
# 1                                 [Drama]    [050]
# 2                                 [Drama]    [117]
# 3                 [Romance, Comedy drama]    [605]
# 4    [Science fiction, Action, Adventure]    [603]
# ..                                    ...      ...
# ...

# %%
df3['genres'] = [', '.join(map(str, l)) for l in df3['genres']]

# %%
df1=df1.dropna(subset=["genres"])

# %%
df1['genres'] = [', '.join(map(str, l)) for l in df1['genres']]
# Out:
# C:\Users\Jyoti\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df3
# Out:
#                                             title  \
# 0                Once Upon a Time... In Hollywood
# 1                                 Freedom Writers
# 2                                 Freedom Writers
# 3                          The American President
# 4                                    Total Recall
# ..                                            ...
# 419                                 Transporter 3
# 420                                 Transporter 3
# 421  Texas Chainsaw Massacre: The Next Generation
# 422                                  Crimson Peak
# 423                                La cara oculta
#
#                                  genres channels
# 0             Comedy drama, Dark comedy    [581]
# 1                                 Drama    [050]
# 2                                 Drama    [117]
# 3                 Romance, Comedy drama    [605]
# 4    Science fiction, Action, Adventure    [603]
# ..                                  ...      ...
# ...

# %%
df1
# Out:
#                                    title  releaseYear  \
# 0                         Turtle Odyssey       2018.0
# 1                    Into America's Wild       2020.0
# 2                                  Tenet       2020.0
# 3                                  Shrek       2001.0
# 4              A Nightmare on Elm Street       1984.0
# 5                            Hocus Pocus       1993.0
# 6                                  Mandy       2018.0
# 7                              Come Play       2020.0
# 8                          The Lost Boys       1987.0
# 9                            The Goonies       1985.0
# 10                           Beetlejuice       1988.0
# 11                                Psycho       1960.0
# 12                            Synchronic       2019.0
# 13                          Honest Thief       2020.0
# 14                           Yellow Rose       2019.0
# 15        The Nightmare Before Christmas       1993.0
# ...

# %%
mergeMoivesData=pd.merge(df1,df3,on='genres')

# %%
mergeMoivesData
# Out:
#                  title_x  releaseYear          genres  \
# 0         Turtle Odyssey       2018.0     Documentary
# 1         Turtle Odyssey       2018.0     Documentary
# 2         Turtle Odyssey       2018.0     Documentary
# 3         Turtle Odyssey       2018.0     Documentary
# 4    Into America's Wild       2020.0     Documentary
# ..                   ...          ...             ...
# 190        Kajillionaire       2020.0    Comedy drama
# 191        Kajillionaire       2020.0    Comedy drama
# 192             2 Hearts       2020.0  Romance, Drama
# 193             2 Hearts       2020.0  Romance, Drama
# 194             2 Hearts       2020.0  Romance, Drama
#
#                                       shortDescription  \
# 0    The unique life cycle of an Australian green s...
# 1    The unique life cycle of an Australian green s...
# 2    The unique life cycle of an Australian green s...
# 3    The unique life cycle of an Australian green s...
# ...

# %%
###TopFive Counts 

mergeMoivesData['genres'].value_counts()
# Out:
# Comedy                                          62
# Horror, Thriller                                60
# Horror                                          28
# Action, Thriller                                14
# Comedy drama                                     9
# Documentary                                      8
# Comedy, Adventure, Animated, Children            4
# Romance, Drama                                   3
# Comedy, Children                                 2
# Fantasy, Comedy, Animated, Children, Holiday     2
# Horror, Comedy                                   1
# Adventure, Comedy, Children                      1
# Dark comedy                                      1
# Name: genres, dtype: int64

# %%
######TopValue count of Genres Movies

# Comedy                                          62
# Horror, Thriller                                60
# Horror                                          28
# Action, Thriller                                14
# Comedy drama                                     9
